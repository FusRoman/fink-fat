# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import exploring_script as es
import importlib
importlib.reload(es)
import pandas as pd
from bin.stat_cli import compute_residue

# %%
res_dict = es.orbfit_perf_results()
# Out:
# current nb point: 3
# current nb point: 4
# current nb point: 5
# current nb point: 6
# current nb point: 7
# current nb point: 8
# current nb point: 9
# current nb point: 10
# current nb point: 15

# %%
es.plot_orbfit_perf(res_dict)

# %%
es.plot_orbfit_diff_hist(res_dict, "da")

# %%
es.plot_orbfit_diff_hist(res_dict, "de")

# %%
es.plot_orbfit_diff_hist(res_dict, "di")
