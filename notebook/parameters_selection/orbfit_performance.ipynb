# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import exploring_script as es
import importlib
importlib.reload(es)
import pandas as pd
from bin.stat_cli import compute_residue

# %%
res_dict = es.orbfit_perf_results()
# Out:
# current nb point: 3
# current nb point: 4
# current nb point: 5
# current nb point: 6
# current nb point: 7
# current nb point: 8
# current nb point: 9
# current nb point: 10
# current nb point: 15

# %%
es.plot_orbfit_perf(res_dict)

# %%
es.plot_orbfit_diff_hist(
    res_dict, 
    "df_with_perf", 
    "da",
    "Distribution of the difference between the estimated orbit parameters with ORBFIT and the MPC orbit parameters",
    "Difference between orbit and MPC (log of the difference in %)",
    "Number of orbit (log)"
)

# %%
es.plot_orbfit_diff_hist(
    res_dict, 
    "df_with_perf", 
    "de",
    "Distribution of the difference between the estimated orbit parameters with ORBFIT and the MPC orbit parameters",
    "Difference between orbit and MPC (log of the difference in %)",
    "Number of orbit (log)"
)

# %%
es.plot_orbfit_diff_hist(
    res_dict, 
    "df_with_perf", 
    "di",
    "Distribution of the difference between the estimated orbit parameters with ORBFIT and the MPC orbit parameters",
    "Difference between orbit and MPC (log of the difference in %)",
    "Number of orbit (log)"
)

# %%
es.plot_orbfit_diff_hist(
    res_dict, 
    "orbit", 
    "rms_a",
    "Distribution of the error on the semi major axis",
    "semi major axis error return by the orbit fitting",
    "Number of orbit"
)
# Out:
# toto

# %%
es.plot_orbfit_diff_hist(
    res_dict, 
    "orbit", 
    "rms_e",
    "Distribution of the error on eccentricity",
    "eccentricity error return by the orbit fitting",
    "Number of orbit"
)

# %%
es.plot_orbfit_diff_hist(
    res_dict, 
    "orbit", 
    "rms_e",
    "Distribution of the error on inclination",
    "inclination error return by the orbit fitting",
    "Number of orbit"
)
